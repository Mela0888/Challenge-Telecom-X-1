# %% [markdown]
# <a href="https://colab.research.google.com/github/Mela0888/Challenge-Telecom-X-1/blob/main/TELECOM_X_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datos = pd.read_json("/content/TelecomX_Data.json")

# %%
datos.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
datos.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %% [markdown]
# En este paso, verifica si hay problemas en los datos que puedan afectar el análisis. Presta atención a valores ausentes, duplicados, errores de formato e inconsistencias en las categorías. Este proceso es esencial para asegurarte de que los datos estén listos para las siguientes etapas.

# %%
datos.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
datos.isnull()
# Out:
#       customerID  Churn  customer  phone  internet  account
# 0          False  False     False  False     False    False
# 1          False  False     False  False     False    False
# 2          False  False     False  False     False    False
# 3          False  False     False  False     False    False
# 4          False  False     False  False     False    False
# ...          ...    ...       ...    ...       ...      ...
# 7262       False  False     False  False     False    False
# 7263       False  False     False  False     False    False
# 7264       False  False     False  False     False    False
# 7265       False  False     False  False     False    False
# 7266       False  False     False  False     False    False
#
# [7267 rows x 6 columns]

# %%
pd.json_normalize(datos["customer"])
pd.json_normalize(datos["phone"])
pd.json_normalize(datos["internet"])
pd.json_normalize(datos["account"])
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
data_normalized = pd.concat([pd.json_normalize(datos["customer"]),
                            pd.json_normalize(datos["phone"]),
                            pd.json_normalize(datos["internet"]),
                            pd.json_normalize(datos["account"])], axis =1)
data_normalized.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes        Yes       9          Yes
# 1    Male              0      No         No       9          Yes
# 2    Male              0      No         No       4          Yes
# 3    Male              1     Yes         No      13          Yes
# 4  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
# 1           Yes             DSL             No           No               No
# 2            No     Fiber optic             No           No              Yes
# 3            No     Fiber optic             No          Yes              Yes
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
cols_to_drop = ["customer", "phone", "internet", "account"]
safe_cols = datos.drop(columns = cols_to_drop, inplace = True)

# %%
datos_normalizados = pd.concat([datos, data_normalized], axis = 1)
pd.DataFrame(datos_normalizados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
datos_normalizados.head(3)
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod Charges.Monthly  Charges.Total
# ...

# %%
print(datos_normalizados.columns)
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
datos_normalizados.columns = datos_normalizados.columns.str.lower()

# %%
print(datos_normalizados.columns)
# Out:
# Index(['customerid', 'churn', 'gender', 'seniorcitizen', 'partner',
#        'dependents', 'tenure', 'phoneservice', 'multiplelines',
#        'internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection',
#        'techsupport', 'streamingtv', 'streamingmovies', 'contract',
#        'paperlessbilling', 'paymentmethod', 'charges.monthly',
#        'charges.total'],
#       dtype='object')

# %%
datos_normalizados = datos_normalizados.rename(columns = {'customerid':"customer_id",
                                                          'seniorcitizen': "senior_citizen",
                                                          'phoneservice': "phone_service",
                                                          'multiplelines': "multiple_line",
                                                          'internetservice': "internet_service",
                                                          'onlinesecurity': "online_security",
                                                          'onlinebackup': "online_backup",
                                                          'deviceprotection': "device_protection",
                                                          'techsupport': "tech_support",
                                                          'streamingtv': "streaming_tv",
                                                          'streamingmovies': "streaming_movies",
                                                          'paperlessbilling': "paper_lessbilling",
                                                          'paymentmethod': "payment_method",
                                                          'charges.monthly': "charges_monthly",
                                                          'charges.total': "charges_total"})

# %%
datos_normalizados
# Out:
#      customer_id churn  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO    No  Female               0     Yes        Yes       9
# 1     0003-MKNFE    No    Male               0      No         No       9
# 2     0004-TLHLJ   Yes    Male               0      No         No       4
# 3     0011-IGKFF   Yes    Male               1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female               1     Yes         No       3
# ...          ...   ...     ...             ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female               0      No         No      13
# 7263  9992-RRAMN   Yes    Male               0     Yes         No      22
# 7264  9992-UJOEL    No    Male               0      No         No       2
# 7265  9993-LHIEB    No    Male               0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male               0     Yes        Yes      63
#
#      phone_service     multiple_line internet_service  ... online_backup  \
# ...

# %%
datos_normalizados = datos_normalizados.applymap(lambda x: x.lower() if isinstance(x, str) else x)
datos_normalizados
# Out:
# /tmp/ipython-input-58-2564437321.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   datos_normalizados = datos_normalizados.applymap(lambda x: x.lower() if isinstance(x, str) else x)
#      customer_id churn  gender  senior_citizen partner dependents  tenure  \
# 0     0002-orfbo    no  female               0     yes        yes       9
# 1     0003-mknfe    no    male               0      no         no       9
# 2     0004-tlhlj   yes    male               0      no         no       4
# 3     0011-igkff   yes    male               1     yes         no      13
# 4     0013-exchz   yes  female               1     yes         no       3
# ...          ...   ...     ...             ...     ...        ...     ...
# 7262  9987-lutyd    no  female               0      no         no      13
# 7263  9992-rramn   yes    male               0     yes         no      22
# 7264  9992-ujoel    no    male               0      no         no       2
# ...

# %%
datos_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7267 non-null   object
#  1   churn              7267 non-null   object
#  2   gender             7267 non-null   object
#  3   senior_citizen     7267 non-null   int64
#  4   partner            7267 non-null   object
#  5   dependents         7267 non-null   object
#  6   tenure             7267 non-null   int64
#  7   phone_service      7267 non-null   object
#  8   multiple_line      7267 non-null   object
#  9   internet_service   7267 non-null   object
#  10  online_security    7267 non-null   object
#  11  online_backup      7267 non-null   object
#  12  device_protection  7267 non-null   object
#  13  tech_support       7267 non-null   object
#  14  streaming_tv       7267 non-null   object
#  15  streaming_movies   7267 non-null   object
# ...

# %%
columnas = list(datos_normalizados.columns)
columnas
for col in columnas:
  print(col)
  print(datos_normalizados[col].unique())
# Out:
# customer_id
# ['0002-orfbo' '0003-mknfe' '0004-tlhlj' ... '9992-ujoel' '9993-lhieb'
#  '9995-hotoh']
# churn
# ['no' 'yes' '']
# gender
# ['female' 'male']
# senior_citizen
# [0 1]
# partner
# ['yes' 'no']
# dependents
# ['yes' 'no']
# tenure
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# phone_service
# ['yes' 'no']
# multiple_line
# ['no' 'yes' 'no phone service']
# internet_service
# ['dsl' 'fiber optic' 'no']
# online_security
# ['no' 'yes' 'no internet service']
# online_backup
# ['yes' 'no' 'no internet service']
# device_protection
# ['no' 'yes' 'no internet service']
# tech_support
# ['yes' 'no' 'no internet service']
# streaming_tv
# ['yes' 'no' 'no internet service']
# streaming_movies
# ['no' 'yes' 'no internet service']
# contract
# ['one year' 'month-to-month' 'two year']
# ...

# %%
datos_normalizados["charges_total"].eq(" ").sum()
# Out:
# np.int64(11)

# %%
columnas_to_modified = ["online_security", "online_backup", "device_protection",
                        "tech_support", "streaming_tv", "streaming_movies"]
datos_normalizados[columnas_to_modified] = datos_normalizados[columnas_to_modified].replace("no internet service", np.nan)
datos_normalizados["multiple_line"] = datos_normalizados["multiple_line"].replace("no phone service", np.nan)
datos_normalizados["internet_service"]= datos_normalizados["internet_service"].replace("no", np.nan)
datos_normalizados["churn"]=datos_normalizados["churn"].replace(" ", np.nan)
datos_normalizados["charges_total"] = datos_normalizados["charges_total"].replace(" ", np.nan)

# %%
datos_normalizados.loc[:, "contract"] = datos_normalizados["contract"].replace({"two year":"biennial",
                                                                                "one year":"yearly",
                                                                                "month-to-month":"monthly"})

# %%
columnas = list(datos_normalizados.columns)
columnas
for col in columnas:
  print(col)
  print(datos_normalizados[col].unique())
# Out:
# customer_id
# ['0002-orfbo' '0003-mknfe' '0004-tlhlj' ... '9992-ujoel' '9993-lhieb'
#  '9995-hotoh']
# churn
# ['no' 'yes' '']
# gender
# ['female' 'male']
# senior_citizen
# [0 1]
# partner
# ['yes' 'no']
# dependents
# ['yes' 'no']
# tenure
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# phone_service
# ['yes' 'no']
# multiple_line
# ['no' 'yes' nan]
# internet_service
# ['dsl' 'fiber optic' nan]
# online_security
# ['no' 'yes' nan]
# online_backup
# ['yes' 'no' nan]
# device_protection
# ['no' 'yes' nan]
# tech_support
# ['yes' 'no' nan]
# streaming_tv
# ['yes' 'no' nan]
# streaming_movies
# ['no' 'yes' nan]
# contract
# ['yearly' 'monthly' 'biennial']
# paper_lessbilling
# ['yes' 'no']
# payment_method
# ['mailed check' 'electronic check' 'credit card (automatic)'
#  'bank transfer (automatic)']
# ...

# %%
print(datos_normalizados[columnas_to_modified].isnull().sum())
# Out:
# online_security      1581
# online_backup        1581
# device_protection    1581
# tech_support         1581
# streaming_tv         1581
# streaming_movies     1581
# dtype: int64

# %%
datos_normalizados = datos_normalizados.dropna()

# %%
datos_normalizados["charges_total"] = datos_normalizados["charges_total"].astype(np.float64)
# Out:
# /tmp/ipython-input-67-1848907817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_normalizados["charges_total"] = datos_normalizados["charges_total"].astype(np.float64)

# %%
datos_normalizados.reset_index(drop = True)
# Out:
#      customer_id churn  gender  senior_citizen partner dependents  tenure  \
# 0     0002-orfbo    no  female               0     yes        yes       9
# 1     0003-mknfe    no    male               0      no         no       9
# 2     0004-tlhlj   yes    male               0      no         no       4
# 3     0011-igkff   yes    male               1     yes         no      13
# 4     0013-exchz   yes  female               1     yes         no       3
# ...          ...   ...     ...             ...     ...        ...     ...
# 4971  9985-mwvix   yes  female               0      no         no       1
# 4972  9987-lutyd    no  female               0      no         no      13
# 4973  9992-rramn   yes    male               0     yes         no      22
# 4974  9992-ujoel    no    male               0      no         no       2
# 4975  9993-lhieb    no    male               0     yes        yes      67
#
#      phone_service multiple_line internet_service  ... online_backup  \
# ...

# %% [markdown]
# Ahora que los datos están limpios, es momento de crear la columna "Cuentas_Diarias". Utiliza la facturación mensual para calcular el valor diario, proporcionando una visión más detallada del comportamiento de los clientes a lo largo del tiempo.

# %%
datos_normalizados["customer_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
col_to_change = ["churn", "partner", "dependents",
                 "phone_service", "multiple_line",
                 "online_backup", "device_protection",
                 "tech_support", "streaming_tv",
                 "streaming_movies", "paper_lessbilling"]
datos_normalizados[col_to_change] = datos_normalizados[col_to_change].replace({"yes": 1, "no":0})
# Out:
# /tmp/ipython-input-70-1969229143.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datos_normalizados[col_to_change] = datos_normalizados[col_to_change].replace({"yes": 1, "no":0})
# /tmp/ipython-input-70-1969229143.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_normalizados[col_to_change] = datos_normalizados[col_to_change].replace({"yes": 1, "no":0})

# %%
datos_normalizados
# Out:
#      customer_id churn  gender  senior_citizen  partner  dependents  tenure  \
# 0     0002-orfbo     0  female               0        1           1       9
# 1     0003-mknfe     0    male               0        0           0       9
# 2     0004-tlhlj     1    male               0        0           0       4
# 3     0011-igkff     1    male               1        1           0      13
# 4     0013-exchz     1  female               1        1           0       3
# ...          ...   ...     ...             ...      ...         ...     ...
# 7260  9985-mwvix     1  female               0        0           0       1
# 7262  9987-lutyd     0  female               0        0           0      13
# 7263  9992-rramn     1    male               0        1           0      22
# 7264  9992-ujoel     0    male               0        0           0       2
# 7265  9993-lhieb     0    male               0        1           1      67
#
# ...

# %%
datos_normalizados["cuentas_diarias"] = round((datos_normalizados["charges_monthly"]/30),2)
# Out:
# /tmp/ipython-input-72-1387943418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_normalizados["cuentas_diarias"] = round((datos_normalizados["charges_monthly"]/30),2)

# %%
datos_normalizados.head()
# Out:
#   customer_id churn  gender  senior_citizen  partner  dependents  tenure  \
# 0  0002-orfbo     0  female               0        1           1       9
# 1  0003-mknfe     0    male               0        0           0       9
# 2  0004-tlhlj     1    male               0        0           0       4
# 3  0011-igkff     1    male               1        1           0      13
# 4  0013-exchz     1  female               1        1           0       3
#
#    phone_service  multiple_line internet_service  ... device_protection  \
# 0              1              0              dsl  ...                 0
# 1              1              1              dsl  ...                 0
# 2              1              0      fiber optic  ...                 1
# 3              1              0      fiber optic  ...                 1
# 4              1              0      fiber optic  ...                 0
#
#    tech_support  streaming_tv  streaming_movies  contract  paper_lessbilling  \
# ...

# %%
datos_normalizados.describe()
# Out:
#        senior_citizen      partner   dependents       tenure  phone_service  \
# count     4976.000000  4976.000000  4976.000000  4976.000000         4976.0
# mean         0.204984     0.487942     0.259646    33.022709            1.0
# std          0.403730     0.499905     0.438485    24.657136            0.0
# min          0.000000     0.000000     0.000000     1.000000            1.0
# 25%          0.000000     0.000000     0.000000     9.000000            1.0
# 50%          0.000000     0.000000     0.000000    30.000000            1.0
# 75%          0.000000     1.000000     1.000000    56.000000            1.0
# max          1.000000     1.000000     1.000000    72.000000            1.0
#
#        multiple_line  online_backup  device_protection  tech_support  \
# count    4976.000000    4976.000000        4976.000000   4976.000000
# mean        0.544011       0.442926           0.436495      0.362138
# std         0.498109       0.496782           0.496001      0.480667
# ...

# %%
datos_servicio = datos_normalizados.copy()

# %%
datos_servicio["internet_service"] = datos_servicio["internet_service"].replace({"fiber optic": 1, "dsl": 0})
datos_servicio.head()
# Out:
# /tmp/ipython-input-76-4024461301.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datos_servicio["internet_service"] = datos_servicio["internet_service"].replace({"fiber optic": 1, "dsl": 0})
#   customer_id churn  gender  senior_citizen  partner  dependents  tenure  \
# 0  0002-orfbo     0  female               0        1           1       9
# 1  0003-mknfe     0    male               0        0           0       9
# 2  0004-tlhlj     1    male               0        0           0       4
# 3  0011-igkff     1    male               1        1           0      13
# 4  0013-exchz     1  female               1        1           0       3
#
#    phone_service  multiple_line  internet_service  ... device_protection  \
# ...

# %%
datos_servicio = datos_servicio.rename(columns = {"internet_service": "fibra_optica", "phone_service":"servicio_telefonico",
                                                  "multiple_line": "multiples_lineas", "internet_service": "servicio_internet",
                                                  "online_security":"seguridad_en_linea","online_backup": "servicio_nube",
                                                  "device_protection": "proteccion_dispositivos", "tech_support": "soporte_tecnico",
                                                  "streaming_tv": "tv_satelital", "streaming_movies": "peliculas_satelital",
                                                  "charges_monthly": "pago_mensual","customer_id":"id_cliente",
                                                  "churn":"batir","gender":"genero","senior_citizen":"ciudadano_mayor",
                                                  "partner":"pareja","dependents":"dependientes","tenure":"tenencia",
                                                  "contract":"contrato","charges_total":"cargos_totales","paper_lessbilling":"facturacion_virtual",
                                                  "payment_method":"metodo_pago"})
datos_servicio.head()
# Out:
#    id_cliente batir  genero  ciudadano_mayor  pareja  dependientes  tenencia  \
# 0  0002-orfbo     0  female                0       1             1         9
# 1  0003-mknfe     0    male                0       0             0         9
# 2  0004-tlhlj     1    male                0       0             0         4
# 3  0011-igkff     1    male                1       1             0        13
# 4  0013-exchz     1  female                1       1             0         3
#
#    servicio_telefonico  multiples_lineas  servicio_internet  ...  \
# 0                    1                 0                  0  ...
# 1                    1                 1                  0  ...
# 2                    1                 0                  1  ...
# 3                    1                 0                  1  ...
# 4                    1                 0                  1  ...
#
#   proteccion_dispositivos  soporte_tecnico  tv_satelital  peliculas_satelital  \
# ...

# %%
datos_servicio.drop(["id_cliente","genero","ciudadano_mayor","pareja",
                     "dependientes","Contrato","facturacion_virtual",
                     "metodo_pago","cargos_totales","cuentas_diarias"],axis = 1, inplace = True)
datos_servicio.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-78-289626792.py in <cell line: 0>()
# ----> 1 datos_servicio.drop(["id_cliente","genero","ciudadano_mayor","pareja",
#       2                      "dependientes","Contrato","facturacion_virtual",
#       3                      "metodo_pago","cargos_totales","cuentas_diarias"],axis = 1, inplace = True)
#       4 datos_servicio.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
datos_servicio["seguridad_en_linea"].replace({"yes":1,"no": 0}, inplace =True)

# %%
datos_servicio = datos_servicio.reset_index(drop = True)
datos_servicio.head(3)

# %%
datos_estatus_usuario = datos_normalizados.copy()
datos_estatus_usuario.head()

# %%
datos_estatus_usuario.drop(["customer_id","senior_citizen","partner","dependents","phone_service",
                            "multiple_line","internet_service","online_security","online_backup",
                            "device_protection","tech_support","streaming_tv","streaming_movies",
                            "paper_lessbilling","charges_total","cuentas_diarias"],axis = 1, inplace = True)

# %%
datos_estatus_usuario.head()

# %%
datos_estatus_usuario = datos_estatus_usuario.rename(columns = {"churn": "cancelacion","gender": "genero",
                                                                "tenure":"permanencia_mensual","contract":"contrato",
                                                                "payment_method":"metodo_pago","charges_monthly":"pago_mensual"})

# %%
datos_estatus_usuario.head()

# %%
datos_estatus_usuario.loc[:, "contrato"] = datos_estatus_usuario["contrato"].replace({"biennial":"bianual",
                                                                                      "yearly":"anual",
                                                                                      "monthly":"mensual"})

# %%
datos_estatus_usuario.loc[:, "metodo_pago"] = datos_estatus_usuario.loc[:,"metodo_pago"].replace({"mailed check":"manual",
                                                                                                  "electronic check":"manual",
                                                                                                  "credit card(automatic)":"automatico",
                                                                                                  "bank transfer(automatic)":"automatico"})

# %%
datos_estatus_usuario.loc[:,"genero"] = datos_estatus_usuario.loc[:,"genero"].replace({"male":"hombre",
                                                                                       "female":"mujer"})

# %%
datos_estatus_usuario.reset_index(drop = True)

# %%
datos_estatus_usuario.to_json("TelecomX_estatus_usuario.json")

# %% [markdown]
# ##**Informe Final**##

# %% [markdown]
# ###**Evasión de Clientes**###

# %% [markdown]
# Se brinda el analisis para verificar cuantos clientes son los que están evadiendo el pago que se acordo al comienzo del periodo de su contrato.

# %% [markdown]
# ###**Limpieza y Tratamiento de Datos**###

# %% [markdown]
# 1.   Se realiza la exportación de los datos que vienen en un formato JSON, el cual se hace con el metódo necesario para visualizar la información.
# 2.   Se limpia la información dado que estaba en un formato que no era el requerido para poder sacar los datos necesarios con los que se puede mostrar el informe.
# 3.   Para procesar los datos se importaron diferentes bibliotedas como numpy, pandas, matplotlib y seaborn.

# %% [markdown]
# ###**Análisis Exploratorio de Datos**###

# %% [markdown]
# Esta función calcula el coeficiente V de Cramer, una medida de asociación entre dos variables categoricas. A diferencia de la correcación , el V Cramer evalúa la fuerza y dirección de la relación entre dos variables categaricas, devolviendo un valor entre 0 y 1. Interpretación del resultado 0: No hay asociación entre variables

# %% [markdown]
# ###**Conclusiones e Insights**###

# %% [markdown]
# Este código genera un papel de visualizaciones diseñado para revelar insights clave sobre el comportamiento del Churn(abandono clientes) en relación con diferentes variables del dataset.
#
# El análisis del comportamiento de los clientes revela patrones claros que explican las tasas de abandono en el servicio.
# Los hallazgos principales muestran que el churn no ocurre aleatoriamente, sino que está fuertemente influenciado por factores específicos que interactuan entre sí de maneraspredecibles. La combinación de contratos a corto plazo, falta de servicio digitales esenciales y métodos de pago inconvenientes crea una tormenta perfecta para la pérdida de clientes.

# %% [markdown]
# ###**Recomendaciones**###

# %% [markdown]
# 1.  Enfoque en contratos anuales: Promover descuentos o beneficios para migrar clientes de planes mensuales a anuales.
# 2.   Retención temporal: Implementar programas de onbording o incentivos para clientes nuevos.
